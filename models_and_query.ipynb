# %%
from inventory.models import *

# %%
Brand.objects.all()
# Out:
# <QuerySet [<Brand: name : Nike  |  tagline : Just Do It>, <Brand: name : Uniliver  |  tagline : make sustainable living commonplace>]>

# %%
Brand.objects
# Out:
# <QuerySet [<Brand: name : Nike  |  tagline : Just Do It>, <Brand: name : Uniliver  |  tagline : make sustainable living commonplace>]>
